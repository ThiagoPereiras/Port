# %%
#Importar Bibliotecas 
#Importar base de dados 
#fazer tratamento da base de dados 
#procurar solução para ver oque esta acontecendo que 26% dos clientes estão cancelando contratos 
#criar graficos com indicadores de serviços e fazer uma super analise

# %%
import pandas as pd

# %%
df = pd.read_csv('telecom_users.csv')
df = df.drop(['Unnamed: 0'], axis=1)
df ['TotalGasto']=pd.to_numeric(df['TotalGasto'],errors='coerce')
df=df.dropna(how='all',axis=1)
df=df.dropna()
display(df['Churn'].value_counts())
display(df['Churn'].value_counts(normalize=True).map('{:.1%}'.format))
display(df)
print(df.info())
# Out:
# Nao    4387
# Sim    1587
# Name: Churn, dtype: int64
# Nao    73.4%
# Sim    26.6%
# Name: Churn, dtype: object
#        IDCliente     Genero  Aposentado Casado Dependentes  MesesComoCliente  \
# 0     7010-BRBUU  Masculino           0    Sim         Sim                72
# 1     9688-YGXVR   Feminino           0    Nao         Nao                44
# 2     9286-DOJGF   Feminino           1    Sim         Nao                38
# 3     6994-KERXL  Masculino           0    Nao         Nao                 4
# 4     2181-UAESM  Masculino           0    Nao         Nao                 2
# ...          ...        ...         ...    ...         ...               ...
# 5981  0684-AOSIH  Masculino           0    Sim         Nao                 1
# 5982  5982-PSMKW   Feminino           0    Sim         Sim                23
# 5983  8044-BGWPI  Masculino           0    Sim         Sim                12
# 5984  7450-NWRTR  Masculino           1    Nao         Nao                12
# ...

# %%
import plotly.express as px

# %%
for coluna in df:
    if coluna !='IDCliente'
    
       fig=px.histogram(df, x=coluna, color 'Chun')
       
       fig.show()
       
    display(df.pivot_table(index='Churn', columns=coluna, aggfunc='count')['IDCliente'])
# Out:
#   File "C:\Users\thper\AppData\Local\Temp\ipykernel_6692\1913098242.py", line 2
#     if coluna !='IDCliente'
#                            ^
# SyntaxError: invalid syntax
